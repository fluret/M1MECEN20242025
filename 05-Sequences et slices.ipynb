# %% [markdown]
# # Introduction

# %% [markdown]
# Nous allons parler d'un ensemble de types qu'on appelle les séquences.
#
# Les séquences en Python regroupent notamment les listes, les tuples, les chaînes de caractères et les bytes. Nous verrons qu'elles regroupent également encore plus de types que cela.
#
# Une séquence en Python est un ensemble fini et ordonné d'éléments, indicés de 0 à n - 1 si j'ai n éléments.

# %% [markdown]
# # Exemples sur des chaines

# %% [markdown]
# Prenons un exemple de séquence et commençons avec une chaîne de caractères.
# Voici une chaîne de caractères :

# %%
s = 'bonjour comment allez vous ?'
! pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# anyio                             4.6.0
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# asttokens                         2.4.1
# async-lru                         2.0.4
# attrs                             24.2.0
# babel                             2.16.0
# beautifulsoup4                    4.12.3
# bleach                            6.1.0
# certifi                           2024.8.30
# cffi                              1.17.1
# charset-normalizer                3.3.2
# colorama                          0.4.6
# comm                              0.2.2
# debugpy                           1.8.5
# decorator                         5.1.1
# defusedxml                        0.7.1
# executing                         2.1.0
# fastjsonschema                    2.20.0
# fqdn                              1.5.1
# ...

# %%
# !pip uninstall -y nbconvert
# Out:
# Found existing installation: nbconvert 7.16.4
# Uninstalling nbconvert-7.16.4:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\shutil.py", line 847, in move
#     os.rename(src, real_dst)
# PermissionError: [WinError 5] Accès refusé: 'c:\\program files\\python312\\lib\\site-packages\\nbconvert-7.16.4.dist-info\\' -> 'C:\\Users\\luret\\AppData\\Local\\Temp\\pip-uninstall-jr1ys5du'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# Je vous rappelle que la chaîne de caractères est juste un exemple de séquence mais que les listes par exemple, ou les tuples, sont également des objets séquences.
#
# Regardons un exemple d'opération que je peux faire, commune à toutes les séquences.
# Je peux déjà commencer par accéder à chaque élément de la séquence, avec la notation crochets.

# %%
s[0]

# %%
s[22]

# %%
s[27]

# %% [markdown]
# s[0] me permet d'accéder au premier élément de la séquence, puisque, je vous le rappelle, les séquences sont numérotées à partir de 0.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">0</th>
#     <th class="tg-0pky">1</th>
#     <th class="tg-0pky">2</th>
#     <th class="tg-0pky">3</th>
#     <th class="tg-0pky">4</th>
#     <th class="tg-0pky">5</th>
#     <th class="tg-0pky">6</th>
#     <th class="tg-0pky">7</th>
#     <th class="tg-0pky">8</th>
#     <th class="tg-0pky">9</th>
#     <th class="tg-0pky">10</th>
#     <th class="tg-0pky">11</th>
#     <th class="tg-0pky">12</th>
#     <th class="tg-0pky">13</th>
#     <th class="tg-0pky">14</th>
#     <th class="tg-0pky">15</th>
#     <th class="tg-0pky">16</th>
#     <th class="tg-0pky">17</th>
#     <th class="tg-0pky">18</th>
#     <th class="tg-0pky">19</th>
#     <th class="tg-0pky">20</th>
#     <th class="tg-0pky">21</th>
#     <th class="tg-0pky">22</th>
#     <th class="tg-0pky">23</th>
#     <th class="tg-0pky">24</th>
#     <th class="tg-0pky">25</th>
#     <th class="tg-0pky">26</th>
#     <th class="tg-0pky">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">b</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">j</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">r</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">c</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">t</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">a</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">z</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">v</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">s</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">?</td>
#   </tr>
# </tbody>
# </table>
#
# s[27] va me permettre d'accéder au dernier élément de ma séquence puisqu'ici, ma séquence a 28 éléments.
#
# La fonction built-in len. Permet de connaître le nombre d'éléments dans ma séquence :

# %%
len(s)

# %% [markdown]
# Toutes les séquences supportent également le test d'appartenance, c'est une opération très puissante en Python puisque je peux faire :

# %%
'comment' in s

# %% [markdown]
# De même, je peux faire un test de non-appartenance :

# %%
'bateau' not in s

# %% [markdown]
# Vous remarquez que ce test est extrêmement expressif, puisque c'est quasiment du langage naturel. Je regarde est-ce que ma chaîne de caractères 'comment' est dans s.
#
# Ensuite, je peux faire de la concaténation de séquences.
#
# On peut rajouter une chaîne de caractères à la chaine s :

# %%
s + ' Bien et vous ?'

# %% [markdown]
# Et cette concaténation va me produire une nouvelle chaîne de caractères puisque les opérations sur les séquences ne les modifient pas, puisque typiquement une chaîne de caractères n'est pas mutable, mais ça retourne un nouvel objet, dans ce cas-là, un nouvel objet de type chaîne de caractères.
#
# J'ai également des opérations comme par exemple index(), qui me permet de trouver la première occurrence par exemple de la lettre g :

# %%
s.index('o')

# %% [markdown]
# Effectivement, la première occurrence de la lettre o, c'est à la place 1.
#
# On a également l'opération count() qui me permet de compter le nombre d'éléments, le nombre de o que j'ai dans ma séquence :

# %%
s.count('o')

# %% [markdown]
# Donc ici, on voit que j'ai 4 fois la lettre o.
#
# Je peux également appliquer les fonctions built-in min() et max(), qui me retournent le minimum et le maximum de ma séquence. Dans ce cas-là, comme c'est une chaîne de caractères, c'est en utilisant l'ordre lexicographique :

# %%
min(s)

# %%
max(s)

# %% [markdown]
# Et j'ai une dernière opération qui est l'opération de shallow copy qui me permet de faire copie n fois d'une chaine :

# %%
'*'*30

# %% [markdown]
# Ici on a effectué une copie 30 fois de la chaîne de caractères '*'.
#
# Nous verrons dans la suite que cette opération produit en fait une shallow copy qui peut avoir des effets de bord lorsque la séquence multipliée n'est pas un immuable mais un objet de type mutable. Mais nous reviendrons sur ça dans la suite.

# %% [markdown]
# # Le slicing

# %% [markdown]
# ## Principe de base

# %% [markdown]
# Nous allons maintenant regarder une dernière opération très importante sur les séquences qui s'appelle l'opération de slicing.
# Pour illustrer cette opération de slicing, qui est valable pour toutes les séquences donc pour les chaînes de caractères puisque c'est l'exemple que l'on va regarder mais également pour les listes, je vais créer une chaîne de caractères :

# %%
s = 'bonjour comment allez vous ?'

# %% [markdown]
# Représentons la chaîne de caractères avec l'indice de chaque élément.
#
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">0</th>
#     <th class="tg-0pky">1</th>
#     <th class="tg-0pky">2</th>
#     <th class="tg-0pky">3</th>
#     <th class="tg-0pky">4</th>
#     <th class="tg-0pky">5</th>
#     <th class="tg-0pky">6</th>
#     <th class="tg-0pky">7</th>
#     <th class="tg-0pky">8</th>
#     <th class="tg-0pky">9</th>
#     <th class="tg-0pky">10</th>
#     <th class="tg-0pky">11</th>
#     <th class="tg-0pky">12</th>
#     <th class="tg-0pky">13</th>
#     <th class="tg-0pky">14</th>
#     <th class="tg-0pky">15</th>
#     <th class="tg-0pky">16</th>
#     <th class="tg-0pky">17</th>
#     <th class="tg-0pky">18</th>
#     <th class="tg-0pky">19</th>
#     <th class="tg-0pky">20</th>
#     <th class="tg-0pky">21</th>
#     <th class="tg-0pky">22</th>
#     <th class="tg-0pky">23</th>
#     <th class="tg-0pky">24</th>
#     <th class="tg-0pky">25</th>
#     <th class="tg-0pky">26</th>
#     <th class="tg-0pky">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">b</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">j</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">r</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">c</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">t</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">a</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">z</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">v</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">s</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">?</td>
#   </tr>
# </tbody>
# </table>
#
#
# On voit que b, c'est l'élément d'indice 0, r, l'élément d'indice 6, le quatrième o, l'élément d'indice 23, etc...
#
# Je vais maintenant faire une opération de slicing. L'opération de slicing se note de la manière suivante :
#
# > s[<span style="color:green">0</span>:<span style="color:red">3</span>]
#
# on va mettre une borne de gauche, deux points, une borne de droite.
# La borne de gauche, en vert, est incluse et la borne de droite est exclue.
# Donc ici, s[0:3] va me retourner tous les éléments qui vont entre 0 inclus et 3 exclu, donc 2
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# .tg .tg-hm9m{background-color:#3531ff;border-color:inherit;color:#fcff2f;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">0</th>
#     <th class="tg-0pky">1</th>
#     <th class="tg-0pky">2</th>
#     <th class="tg-0pky">3</th>
#     <th class="tg-0pky">4</th>
#     <th class="tg-0pky">5</th>
#     <th class="tg-0pky">6</th>
#     <th class="tg-0pky">7</th>
#     <th class="tg-0pky">8</th>
#     <th class="tg-0pky">9</th>
#     <th class="tg-0pky">10</th>
#     <th class="tg-0pky">11</th>
#     <th class="tg-0pky">12</th>
#     <th class="tg-0pky">13</th>
#     <th class="tg-0pky">14</th>
#     <th class="tg-0pky">15</th>
#     <th class="tg-0pky">16</th>
#     <th class="tg-0pky">17</th>
#     <th class="tg-0pky">18</th>
#     <th class="tg-0pky">19</th>
#     <th class="tg-0pky">20</th>
#     <th class="tg-0pky">21</th>
#     <th class="tg-0pky">22</th>
#     <th class="tg-0pky">23</th>
#     <th class="tg-0pky">24</th>
#     <th class="tg-0pky">25</th>
#     <th class="tg-0pky">26</th>
#     <th class="tg-0pky">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-hm9m">b</td>
#     <td class="tg-hm9m">o</td>
#     <td class="tg-hm9m">n</td>
#     <td class="tg-0pky">j</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">r</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">c</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">t</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">a</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">z</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">v</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">s</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">?</td>
#   </tr>
# </tbody>
# </table>

# %%
s[0:3]

# %% [markdown]
# ### Conventions de début et fin

# %% [markdown]
# Les débutants ont parfois du mal avec les bornes. Il faut se souvenir que :
#
# * les indices **commencent** comme toujours **à zéro** ;
# * le premier indice `debut` est **inclus** ;
# * le second indice `fin` est **exclu** ;
# * on obtient en tout `fin-debut` items dans le résultat.
#
# Ainsi, ci-dessus, le résultat contient `6 - 2 = 4` éléments.

# %% [markdown]
# Pour vous aider à vous souvenir des conventions de début et de fin, souvenez-vous qu'on veut pouvoir facilement juxtaposer deux slices qui ont une borne commune.
#
# C'est-à-dire qu'avec :

# %% [markdown]
# ![début et fin](img/brackets.png)

# %%
# s[a:b] + s[b:c] == s[a:c]
s[0:3] + s[3:7] == s[0:7]

# %% [markdown]
# Il est très important de comprendre que l'opération de slice retourne à chaque fois un nouvel objet.
#
# Prenons un deuxième exemple, s[5:10], ça va me retourner tous les éléments allant de 5 inclus à 10 exclu, 10 moins 1, ça fait 9 :
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-3s1s{background-color:#3166ff;color:#f8ff00;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">0</th>
#     <th class="tg-0lax">1</th>
#     <th class="tg-0lax">2</th>
#     <th class="tg-0lax">3</th>
#     <th class="tg-0lax">4</th>
#     <th class="tg-0lax">5</th>
#     <th class="tg-0lax">6</th>
#     <th class="tg-0lax">7</th>
#     <th class="tg-0lax">8</th>
#     <th class="tg-0lax">9</th>
#     <th class="tg-0lax">10</th>
#     <th class="tg-0lax">11</th>
#     <th class="tg-0lax">12</th>
#     <th class="tg-0lax">13</th>
#     <th class="tg-0lax">14</th>
#     <th class="tg-0lax">15</th>
#     <th class="tg-0lax">16</th>
#     <th class="tg-0lax">17</th>
#     <th class="tg-0lax">18</th>
#     <th class="tg-0lax">19</th>
#     <th class="tg-0lax">20</th>
#     <th class="tg-0lax">21</th>
#     <th class="tg-0lax">22</th>
#     <th class="tg-0lax">23</th>
#     <th class="tg-0lax">24</th>
#     <th class="tg-0lax">25</th>
#     <th class="tg-0lax">26</th>
#     <th class="tg-0lax">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">b</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">n</td>
#     <td class="tg-0lax">j</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-3s1s">u</td>
#     <td class="tg-3s1s">r</td>
#     <td class="tg-3s1s"> </td>
#     <td class="tg-3s1s">c</td>
#     <td class="tg-3s1s">o</td>
#     <td class="tg-0lax">m</td>
#     <td class="tg-0lax">m</td>
#     <td class="tg-0lax">e</td>
#     <td class="tg-0lax">n</td>
#     <td class="tg-0lax">t</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">a</td>
#     <td class="tg-0lax">l</td>
#     <td class="tg-0lax">l</td>
#     <td class="tg-0lax">e</td>
#     <td class="tg-0lax">z</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">v</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">u</td>
#     <td class="tg-0lax">s</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">?</td>
#   </tr>
# </tbody>
# </table>

# %%
s[5:10]

# %% [markdown]
# Si je fais s[:15], si vous ne spécifiez pas la borne de gauche, vous allez parcourir tous les éléments du début jusqu'au 15 exclu, ça va donc me parcourir tous les éléments allant de l'index 0 soit "b" jusqu'à 15 exclu, c'est-à-dire 14 :
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# .tg .tg-2pia{background-color:#3531ff;color:#f8ff00;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">0</th>
#     <th class="tg-0lax">1</th>
#     <th class="tg-0lax">2</th>
#     <th class="tg-0lax">3</th>
#     <th class="tg-0lax">4</th>
#     <th class="tg-0lax">5</th>
#     <th class="tg-0lax">6</th>
#     <th class="tg-0lax">7</th>
#     <th class="tg-0lax">8</th>
#     <th class="tg-0lax">9</th>
#     <th class="tg-0lax">10</th>
#     <th class="tg-0lax">11</th>
#     <th class="tg-0lax">12</th>
#     <th class="tg-0lax">13</th>
#     <th class="tg-0lax">14</th>
#     <th class="tg-0lax">15</th>
#     <th class="tg-0lax">16</th>
#     <th class="tg-0lax">17</th>
#     <th class="tg-0lax">18</th>
#     <th class="tg-0lax">19</th>
#     <th class="tg-0lax">20</th>
#     <th class="tg-0lax">21</th>
#     <th class="tg-0lax">22</th>
#     <th class="tg-0lax">23</th>
#     <th class="tg-0lax">24</th>
#     <th class="tg-0lax">25</th>
#     <th class="tg-0lax">26</th>
#     <th class="tg-0lax">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-2pia">b</td>
#     <td class="tg-2pia">o</td>
#     <td class="tg-2pia">n</td>
#     <td class="tg-2pia">j</td>
#     <td class="tg-2pia">o</td>
#     <td class="tg-2pia">u</td>
#     <td class="tg-2pia">r</td>
#     <td class="tg-2pia"> </td>
#     <td class="tg-2pia">c</td>
#     <td class="tg-2pia">o</td>
#     <td class="tg-2pia">m</td>
#     <td class="tg-2pia">m</td>
#     <td class="tg-2pia">e</td>
#     <td class="tg-2pia">n</td>
#     <td class="tg-2pia">t</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">a</td>
#     <td class="tg-0lax">l</td>
#     <td class="tg-0lax">l</td>
#     <td class="tg-0lax">e</td>
#     <td class="tg-0lax">z</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">v</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">u</td>
#     <td class="tg-0lax">s</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">?</td>
#   </tr>
# </tbody>
# </table>

# %%
s[:15]

# %% [markdown]
# Et si vous ne spécifiez pas la borne de droite, ça va vous retourner tous les éléments allant de 16 jusqu'à la fin :

# %%
s[16:]

# %% [markdown]
# Pour finir, si vous ne spécifiez ni la borne de gauche, ni la borne de droite, ça vous retourne la chaîne de caractères mais c'est important : cette opération de slice ne va pas vous retourner la chaîne de caractères elle-même, ça va vous retourner une copie de cette chaîne de caractères. En fait, nous verrons dans la suite qu'on appelle cette opération une opération de shallow copy :

# %%
s[:]

# %% [markdown]
# ## Notion de pas

# %% [markdown]
# On va rajouter à notre slice la notion de pas. Dans un slice, on peut donner une borne de droite, une borne de gauche et également un pas, c'est-à-dire, on va parcourir les éléments un sur deux si on donne un pas de deux.
#
# Regardons cet exemple :

# %%
s[8:25:2]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-8ytw{background-color:#3531ff;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# .tg .tg-n3w3{background-color:#3531ff;color:#f8ff00;font-weight:bold;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">0</th>
#     <th class="tg-0lax">1</th>
#     <th class="tg-0lax">2</th>
#     <th class="tg-0lax">3</th>
#     <th class="tg-0lax">4</th>
#     <th class="tg-0lax">5</th>
#     <th class="tg-0lax">6</th>
#     <th class="tg-0lax">7</th>
#     <th class="tg-0lax">8</th>
#     <th class="tg-0lax">9</th>
#     <th class="tg-0lax">10</th>
#     <th class="tg-0lax">11</th>
#     <th class="tg-0lax">12</th>
#     <th class="tg-0lax">13</th>
#     <th class="tg-0lax">14</th>
#     <th class="tg-0lax">15</th>
#     <th class="tg-0lax">16</th>
#     <th class="tg-0lax">17</th>
#     <th class="tg-0lax">18</th>
#     <th class="tg-0lax">19</th>
#     <th class="tg-0lax">20</th>
#     <th class="tg-0lax">21</th>
#     <th class="tg-0lax">22</th>
#     <th class="tg-0lax">23</th>
#     <th class="tg-0lax">24</th>
#     <th class="tg-0lax">25</th>
#     <th class="tg-0lax">26</th>
#     <th class="tg-0lax">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">b</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">n</td>
#     <td class="tg-0lax">j</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">u</td>
#     <td class="tg-0lax">r</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-n3w3">c</td>
#     <td class="tg-8ytw">o</td>
#     <td class="tg-n3w3">m</td>
#     <td class="tg-8ytw">m</td>
#     <td class="tg-n3w3">e</td>
#     <td class="tg-8ytw">n</td>
#     <td class="tg-n3w3">t</td>
#     <td class="tg-8ytw"> </td>
#     <td class="tg-n3w3">a</td>
#     <td class="tg-8ytw">l</td>
#     <td class="tg-n3w3">l</td>
#     <td class="tg-8ytw">e</td>
#     <td class="tg-n3w3">z</td>
#     <td class="tg-8ytw"> </td>
#     <td class="tg-n3w3">v</td>
#     <td class="tg-8ytw">o</td>
#     <td class="tg-n3w3">u</td>
#     <td class="tg-0lax">s</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">?</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# On va parcourir les éléments allant de 8 à 25 exclu par pas de 2. C'est-à-dire la chaine 'cmetalzvu'.
# Maintenant, prenons s[ : :2]. Ça me parcourt tous les éléments allant du début à la fin par pas de 2.

# %%
s[::2]

# %%
s[:16:3]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-o84c{background-color:#3531ff;color:#f8ff00;font-style:italic;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-8ytw{background-color:#3531ff;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">0</th>
#     <th class="tg-0lax">1</th>
#     <th class="tg-0lax">2</th>
#     <th class="tg-0lax">3</th>
#     <th class="tg-0lax">4</th>
#     <th class="tg-0lax">5</th>
#     <th class="tg-0lax">6</th>
#     <th class="tg-0lax">7</th>
#     <th class="tg-0lax">8</th>
#     <th class="tg-0lax">9</th>
#     <th class="tg-0lax">10</th>
#     <th class="tg-0lax">11</th>
#     <th class="tg-0lax">12</th>
#     <th class="tg-0lax">13</th>
#     <th class="tg-0lax">14</th>
#     <th class="tg-0lax">15</th>
#     <th class="tg-0lax">16</th>
#     <th class="tg-0lax">17</th>
#     <th class="tg-0lax">18</th>
#     <th class="tg-0lax">19</th>
#     <th class="tg-0lax">20</th>
#     <th class="tg-0lax">21</th>
#     <th class="tg-0lax">22</th>
#     <th class="tg-0lax">23</th>
#     <th class="tg-0lax">24</th>
#     <th class="tg-0lax">25</th>
#     <th class="tg-0lax">26</th>
#     <th class="tg-0lax">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-o84c">b</td>
#     <td class="tg-8ytw">o</td>
#     <td class="tg-8ytw">n</td>
#     <td class="tg-o84c">j</td>
#     <td class="tg-8ytw">o</td>
#     <td class="tg-8ytw">u</td>
#     <td class="tg-o84c">r</td>
#     <td class="tg-8ytw"> </td>
#     <td class="tg-8ytw">c</td>
#     <td class="tg-o84c">o</td>
#     <td class="tg-8ytw">m</td>
#     <td class="tg-8ytw">m</td>
#     <td class="tg-o84c">e</td>
#     <td class="tg-8ytw">n</td>
#     <td class="tg-8ytw">t</td>
#     <td class="tg-o84c"> </td>
#     <td class="tg-0lax">a</td>
#     <td class="tg-0lax">l</td>
#     <td class="tg-0lax">l</td>
#     <td class="tg-0lax">e</td>
#     <td class="tg-0lax">z</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">v</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">u</td>
#     <td class="tg-0lax">s</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">?</td>
#   </tr>
# </tbody>
# </table>

# %%
s[3::4]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-p8sw{background-color:#3166ff;border-color:#fd6864;color:#f8ff00;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# .tg .tg-o79m{background-color:#3166ff;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">0</th>
#     <th class="tg-0lax">1</th>
#     <th class="tg-0lax">2</th>
#     <th class="tg-0lax">3</th>
#     <th class="tg-0lax">4</th>
#     <th class="tg-0lax">5</th>
#     <th class="tg-0lax">6</th>
#     <th class="tg-0lax">7</th>
#     <th class="tg-0lax">8</th>
#     <th class="tg-0lax">9</th>
#     <th class="tg-0lax">10</th>
#     <th class="tg-0lax">11</th>
#     <th class="tg-0lax">12</th>
#     <th class="tg-0lax">13</th>
#     <th class="tg-0lax">14</th>
#     <th class="tg-0lax">15</th>
#     <th class="tg-0lax">16</th>
#     <th class="tg-0lax">17</th>
#     <th class="tg-0lax">18</th>
#     <th class="tg-0lax">19</th>
#     <th class="tg-0lax">20</th>
#     <th class="tg-0lax">21</th>
#     <th class="tg-0lax">22</th>
#     <th class="tg-0lax">23</th>
#     <th class="tg-0lax">24</th>
#     <th class="tg-0lax">25</th>
#     <th class="tg-0lax">26</th>
#     <th class="tg-0lax">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">b</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">n</td>
#     <td class="tg-p8sw">j</td>
#     <td class="tg-o79m">o</td>
#     <td class="tg-o79m">u</td>
#     <td class="tg-o79m">r</td>
#     <td class="tg-p8sw"> </td>
#     <td class="tg-o79m">c</td>
#     <td class="tg-o79m">o</td>
#     <td class="tg-o79m">m</td>
#     <td class="tg-p8sw">m</td>
#     <td class="tg-o79m">e</td>
#     <td class="tg-o79m">n</td>
#     <td class="tg-o79m">t</td>
#     <td class="tg-p8sw"> </td>
#     <td class="tg-o79m">a</td>
#     <td class="tg-o79m">l</td>
#     <td class="tg-o79m">l</td>
#     <td class="tg-p8sw">e</td>
#     <td class="tg-o79m">z</td>
#     <td class="tg-o79m"> </td>
#     <td class="tg-o79m">v</td>
#     <td class="tg-p8sw">o</td>
#     <td class="tg-o79m">u</td>
#     <td class="tg-o79m">s</td>
#     <td class="tg-o79m"> </td>
#     <td class="tg-p8sw">?</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Index inconnu

# %% [markdown]
# Qu'est-ce qu'il se passe si je fais s[100] ? s[100], c'est un indice qui est en dehors de ma chaîne de caractères, je vais donc avoir une erreur qu'on appelle une exception. Mon exception, comme toujours en Python, est très explicite ; elle s'appelle IndexError et elle m'écrit le message d'erreur : string index out of range, ça veut dire que l'indice de ma chaîne de caractères est en dehors des indices couverts par cette chaîne.

# %%
s[100]

# %% [markdown]
# Par contre, si maintenant, je fais s[16:100], je vais obtenir tous les éléments qui vont de 5 jusqu'à la fin de la chaîne de caractères. Pourquoi est-ce que dans ce cas-là je n'ai pas d'erreur ? Parce qu'en fait, le slice est un objet et Python va faire l'opération suivante : il va prendre tous les indices couverts par le slice, donc les indices allant de 5 à 100, et il va chercher l'intersection avec les indices disponibles dans notre objet chaîne de caractères. Et il va retourner uniquement les éléments qui sont à l'intersection.

# %%
s[16:100]

# %% [markdown]
# Ici on voit que l'intersection est non nulle.
# Si je fais un slice de 100 à 200, dans ce cas-là, les indices représentés par le slice et les indices représentés par ma chaîne de caractères n'ont pas d'intersection, donc mon slice va me retourner un objet, toujours de type chaîne de caractères, mais qui est vide.

# %%
s[100:200]

# %% [markdown]
# ## Indices négatifs

# %% [markdown]
# Pour finir avec les chaînes de caractères, nous allons parler des indices négatifs. Voyons l'exemple suivant :

# %%
s[-20:-9]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# .tg .tg-9caq{background-color:#3166ff;color:#f8ff00;font-style:italic;font-weight:bold;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">0</th>
#     <th class="tg-0lax">1</th>
#     <th class="tg-0lax">2</th>
#     <th class="tg-0lax">3</th>
#     <th class="tg-0lax">4</th>
#     <th class="tg-0lax">5</th>
#     <th class="tg-0lax">6</th>
#     <th class="tg-0lax">7</th>
#     <th class="tg-0lax">8</th>
#     <th class="tg-0lax">9</th>
#     <th class="tg-0lax">10</th>
#     <th class="tg-0lax">11</th>
#     <th class="tg-0lax">12</th>
#     <th class="tg-0lax">13</th>
#     <th class="tg-0lax">14</th>
#     <th class="tg-0lax">15</th>
#     <th class="tg-0lax">16</th>
#     <th class="tg-0lax">17</th>
#     <th class="tg-0lax">18</th>
#     <th class="tg-0lax">19</th>
#     <th class="tg-0lax">20</th>
#     <th class="tg-0lax">21</th>
#     <th class="tg-0lax">22</th>
#     <th class="tg-0lax">23</th>
#     <th class="tg-0lax">24</th>
#     <th class="tg-0lax">25</th>
#     <th class="tg-0lax">26</th>
#     <th class="tg-0lax">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">b</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">n</td>
#     <td class="tg-0lax">j</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">u</td>
#     <td class="tg-0lax">r</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-9caq">c</td>
#     <td class="tg-9caq">o</td>
#     <td class="tg-9caq">m</td>
#     <td class="tg-9caq">m</td>
#     <td class="tg-9caq">e</td>
#     <td class="tg-9caq">n</td>
#     <td class="tg-9caq">t</td>
#     <td class="tg-9caq"> </td>
#     <td class="tg-9caq">a</td>
#     <td class="tg-9caq">l</td>
#     <td class="tg-9caq">l</td>
#     <td class="tg-0lax">e</td>
#     <td class="tg-0lax">z</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">v</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">u</td>
#     <td class="tg-0lax">s</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">?</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">-28</td>
#     <td class="tg-0lax">-27</td>
#     <td class="tg-0lax">-26</td>
#     <td class="tg-0lax">-25</td>
#     <td class="tg-0lax">-24</td>
#     <td class="tg-0lax">-23</td>
#     <td class="tg-0lax">-22</td>
#     <td class="tg-0lax">-21</td>
#     <td class="tg-0lax">-20</td>
#     <td class="tg-0lax">-19</td>
#     <td class="tg-0lax">-18<br></td>
#     <td class="tg-0lax">-17</td>
#     <td class="tg-0lax">-16</td>
#     <td class="tg-0lax">-15</td>
#     <td class="tg-0lax">-14<br></td>
#     <td class="tg-0lax">-13</td>
#     <td class="tg-0lax">-12</td>
#     <td class="tg-0lax">-11</td>
#     <td class="tg-0lax">-10</td>
#     <td class="tg-0lax">-9</td>
#     <td class="tg-0lax">-8</td>
#     <td class="tg-0lax">-7</td>
#     <td class="tg-0lax">-6</td>
#     <td class="tg-0lax">-5</td>
#     <td class="tg-0lax">-4</td>
#     <td class="tg-0lax">-3</td>
#     <td class="tg-0lax">-2</td>
#     <td class="tg-0lax">-1</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# Les indices négatifs, c'est comme les indices positifs sauf qu'ils sont numérotés à partir de la fin.
# C'est donc un moyen très commode d'accéder aux derniers éléments d'une séquence lorsqu'on sait leur position à la fin de la séquence.
#
# Donc s[-20:-9] va me retourner tous les éléments allant de -20 inclus jusqu'à -9 exclu.
#
# Ce n'est pas parce que j'ai des indices négatifs que je parcours ma séquence dans un autre sens ; je parcours toujours ma séquence de la gauche vers la droite.

# %%
s[:-7]

# %% [markdown]
# Renvoi tous les éléments du début jusqu'à -7 exclu.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# .tg .tg-9caq{background-color:#3166ff;color:#f8ff00;font-style:italic;font-weight:bold;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">0</th>
#     <th class="tg-0lax">1</th>
#     <th class="tg-0lax">2</th>
#     <th class="tg-0lax">3</th>
#     <th class="tg-0lax">4</th>
#     <th class="tg-0lax">5</th>
#     <th class="tg-0lax">6</th>
#     <th class="tg-0lax">7</th>
#     <th class="tg-0lax">8</th>
#     <th class="tg-0lax">9</th>
#     <th class="tg-0lax">10</th>
#     <th class="tg-0lax">11</th>
#     <th class="tg-0lax">12</th>
#     <th class="tg-0lax">13</th>
#     <th class="tg-0lax">14</th>
#     <th class="tg-0lax">15</th>
#     <th class="tg-0lax">16</th>
#     <th class="tg-0lax">17</th>
#     <th class="tg-0lax">18</th>
#     <th class="tg-0lax">19</th>
#     <th class="tg-0lax">20</th>
#     <th class="tg-0lax">21</th>
#     <th class="tg-0lax">22</th>
#     <th class="tg-0lax">23</th>
#     <th class="tg-0lax">24</th>
#     <th class="tg-0lax">25</th>
#     <th class="tg-0lax">26</th>
#     <th class="tg-0lax">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-9caq">b</td>
#     <td class="tg-9caq">o</td>
#     <td class="tg-9caq">n</td>
#     <td class="tg-9caq">j</td>
#     <td class="tg-9caq">o</td>
#     <td class="tg-9caq">u</td>
#     <td class="tg-9caq">r</td>
#     <td class="tg-9caq"> </td>
#     <td class="tg-9caq">c</td>
#     <td class="tg-9caq">o</td>
#     <td class="tg-9caq">m</td>
#     <td class="tg-9caq">m</td>
#     <td class="tg-9caq">e</td>
#     <td class="tg-9caq">n</td>
#     <td class="tg-9caq">t</td>
#     <td class="tg-9caq"> </td>
#     <td class="tg-9caq">a</td>
#     <td class="tg-9caq">l</td>
#     <td class="tg-9caq">l</td>
#     <td class="tg-9caq">e</td>
#     <td class="tg-9caq">z</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">v</td>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">u</td>
#     <td class="tg-0lax">s</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">?</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">-28</td>
#     <td class="tg-0lax">-27</td>
#     <td class="tg-0lax">-26</td>
#     <td class="tg-0lax">-25</td>
#     <td class="tg-0lax">-24</td>
#     <td class="tg-0lax">-23</td>
#     <td class="tg-0lax">-22</td>
#     <td class="tg-0lax">-21</td>
#     <td class="tg-0lax">-20</td>
#     <td class="tg-0lax">-19</td>
#     <td class="tg-0lax">-18<br></td>
#     <td class="tg-0lax">-17</td>
#     <td class="tg-0lax">-16</td>
#     <td class="tg-0lax">-15</td>
#     <td class="tg-0lax">-14<br></td>
#     <td class="tg-0lax">-13</td>
#     <td class="tg-0lax">-12</td>
#     <td class="tg-0lax">-11</td>
#     <td class="tg-0lax">-10</td>
#     <td class="tg-0lax">-9</td>
#     <td class="tg-0lax">-8</td>
#     <td class="tg-0lax">-7</td>
#     <td class="tg-0lax">-6</td>
#     <td class="tg-0lax">-5</td>
#     <td class="tg-0lax">-4</td>
#     <td class="tg-0lax">-3</td>
#     <td class="tg-0lax">-2</td>
#     <td class="tg-0lax">-1</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# Et si maintenant je fais s[ : :-1], le pas étant négatif, cette fois, ça va parcourir ma séquence dans le sens inverse, de la droite vers la gauche. C'est donc une notation qui est très souvent utilisée pour renverser une séquence.
#
# Donc s[ : : -1] va me retourner ma séquence et l'afficher dans l'ordre inverse.

# %%
s[ : : -1]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">0</th>
#     <th class="tg-0pky">1</th>
#     <th class="tg-0pky">2</th>
#     <th class="tg-0pky">3</th>
#     <th class="tg-0pky">4</th>
#     <th class="tg-0pky">5</th>
#     <th class="tg-0pky">6</th>
#     <th class="tg-0pky">7</th>
#     <th class="tg-0pky">8</th>
#     <th class="tg-0pky">9</th>
#     <th class="tg-0pky">10</th>
#     <th class="tg-0pky">11</th>
#     <th class="tg-0pky">12</th>
#     <th class="tg-0pky">13</th>
#     <th class="tg-0pky">14</th>
#     <th class="tg-0pky">15</th>
#     <th class="tg-0pky">16</th>
#     <th class="tg-0pky">17</th>
#     <th class="tg-0pky">18</th>
#     <th class="tg-0pky">19</th>
#     <th class="tg-0pky">20</th>
#     <th class="tg-0pky">21</th>
#     <th class="tg-0pky">22</th>
#     <th class="tg-0pky">23</th>
#     <th class="tg-0pky">24</th>
#     <th class="tg-0pky">25</th>
#     <th class="tg-0pky">26</th>
#     <th class="tg-0pky">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">b</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">j</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">r</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">c</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">t</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">a</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">z</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">v</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">s</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">?</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# Si maintenant, je fais s[14:7:-1], ça va m'inverser ma séquence et prendre un sous-ensemble allant de droite à gauche, donc allant de 14 inclus jusqu'à 7.

# %%
s[14:7:-1]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">0</th>
#     <th class="tg-0pky">1</th>
#     <th class="tg-0pky">2</th>
#     <th class="tg-0pky">3</th>
#     <th class="tg-0pky">4</th>
#     <th class="tg-0pky">5</th>
#     <th class="tg-0pky">6</th>
#     <th class="tg-0pky">7</th>
#     <th class="tg-0pky">8</th>
#     <th class="tg-0pky">9</th>
#     <th class="tg-0pky">10</th>
#     <th class="tg-0pky">11</th>
#     <th class="tg-0pky">12</th>
#     <th class="tg-0pky">13</th>
#     <th class="tg-0pky">14</th>
#     <th class="tg-0pky">15</th>
#     <th class="tg-0pky">16</th>
#     <th class="tg-0pky">17</th>
#     <th class="tg-0pky">18</th>
#     <th class="tg-0pky">19</th>
#     <th class="tg-0pky">20</th>
#     <th class="tg-0pky">21</th>
#     <th class="tg-0pky">22</th>
#     <th class="tg-0pky">23</th>
#     <th class="tg-0pky">24</th>
#     <th class="tg-0pky">25</th>
#     <th class="tg-0pky">26</th>
#     <th class="tg-0pky">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">b</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">j</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">r</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">c</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">t</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">a</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">z</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">v</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">s</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">?</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# Si je fais s[14 : : -1], ça me retourne ma séquence en allant de 14 jusqu'au début.

# %%
s[14::-1]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">0</th>
#     <th class="tg-0pky">1</th>
#     <th class="tg-0pky">2</th>
#     <th class="tg-0pky">3</th>
#     <th class="tg-0pky">4</th>
#     <th class="tg-0pky">5</th>
#     <th class="tg-0pky">6</th>
#     <th class="tg-0pky">7</th>
#     <th class="tg-0pky">8</th>
#     <th class="tg-0pky">9</th>
#     <th class="tg-0pky">10</th>
#     <th class="tg-0pky">11</th>
#     <th class="tg-0pky">12</th>
#     <th class="tg-0pky">13</th>
#     <th class="tg-0pky">14</th>
#     <th class="tg-0pky">15</th>
#     <th class="tg-0pky">16</th>
#     <th class="tg-0pky">17</th>
#     <th class="tg-0pky">18</th>
#     <th class="tg-0pky">19</th>
#     <th class="tg-0pky">20</th>
#     <th class="tg-0pky">21</th>
#     <th class="tg-0pky">22</th>
#     <th class="tg-0pky">23</th>
#     <th class="tg-0pky">24</th>
#     <th class="tg-0pky">25</th>
#     <th class="tg-0pky">26</th>
#     <th class="tg-0pky">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">b</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">j</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">r</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">c</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">t</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">a</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">z</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">v</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">s</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">?</td>
#   </tr>
# </tbody>
# </table>

# %%
s[14:23:-1]

# %%
s[14:-19:-1]

# %%
s[3:-3:2]

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky">0</th>
#     <th class="tg-0pky">1</th>
#     <th class="tg-0pky">2</th>
#     <th class="tg-0pky">3</th>
#     <th class="tg-0pky">4</th>
#     <th class="tg-0pky">5</th>
#     <th class="tg-0pky">6</th>
#     <th class="tg-0pky">7</th>
#     <th class="tg-0pky">8</th>
#     <th class="tg-0pky">9</th>
#     <th class="tg-0pky">10</th>
#     <th class="tg-0pky">11</th>
#     <th class="tg-0pky">12</th>
#     <th class="tg-0pky">13</th>
#     <th class="tg-0pky">14</th>
#     <th class="tg-0pky">15</th>
#     <th class="tg-0pky">16</th>
#     <th class="tg-0pky">17</th>
#     <th class="tg-0pky">18</th>
#     <th class="tg-0pky">19</th>
#     <th class="tg-0pky">20</th>
#     <th class="tg-0pky">21</th>
#     <th class="tg-0pky">22</th>
#     <th class="tg-0pky">23</th>
#     <th class="tg-0pky">24</th>
#     <th class="tg-0pky">25</th>
#     <th class="tg-0pky">26</th>
#     <th class="tg-0pky">27</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">b</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">j</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">r</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">c</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">m</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">n</td>
#     <td class="tg-0pky">t</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">a</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">l</td>
#     <td class="tg-0pky">e</td>
#     <td class="tg-0pky">z</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">v</td>
#     <td class="tg-0pky">o</td>
#     <td class="tg-0pky">u</td>
#     <td class="tg-0pky">s</td>
#     <td class="tg-0pky"> </td>
#     <td class="tg-0pky">?</td>
#   </tr>
# </tbody>
# </table>
